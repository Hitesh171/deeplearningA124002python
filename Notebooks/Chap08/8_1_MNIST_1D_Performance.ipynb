# %% [markdown]
# <a href="https://colab.research.google.com/github/Hitesh171/deeplearningA124002python/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-bnt5u0dd
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-bnt5u0dd
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (1.15.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.4.26)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14663 sha256=5bcb4c3ebcf73f6c6117f1b64e27b9c8a231466cdccb225f5d3712a201dc19b4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xvzqvvk3/wheels/d6/38/42/3d2112bc7d915f6195254ac85eb761d922d1b18f52817aa8e2
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions
# TODO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = torch.nn.Sequential(torch.nn.Linear(D_i, D_o));


def weights_init(layer_in):
  # TODO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  print("Initializing layer")


# Call the function you just defined
model.apply(weights_init)
# Out:
# Initializing layer
# Initializing layer
# Sequential(
#   (0): Linear(in_features=40, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initializing layer
# Initializing layer
# Epoch     0, train loss 1.743282, train error 69.95,  test loss 1.772806, test error 73.70
# Epoch     1, train loss 1.673177, train error 67.03,  test loss 1.695847, test error 68.80
# Epoch     2, train loss 1.655569, train error 66.20,  test loss 1.693758, test error 70.10
# Epoch     3, train loss 1.646084, train error 66.40,  test loss 1.686211, test error 68.90
# Epoch     4, train loss 1.638288, train error 65.38,  test loss 1.680030, test error 69.70
# Epoch     5, train loss 1.631319, train error 63.97,  test loss 1.685160, test error 71.20
# Epoch     6, train loss 1.618581, train error 64.47,  test loss 1.665138, test error 66.50
# Epoch     7, train loss 1.615021, train error 64.68,  test loss 1.668208, test error 68.00
# Epoch     8, train loss 1.623194, train error 64.47,  test loss 1.670734, test error 67.90
# Epoch     9, train loss 1.624552, train error 64.10,  test loss 1.683808, test error 68.00
# Epoch    10, train loss 1.601633, train error 63.33,  test loss 1.657142, test error 66.40
# Epoch    11, train loss 1.601891, train error 63.47,  test loss 1.655041, test error 66.70
# Epoch    12, train loss 1.597504, train error 63.55,  test loss 1.657377, test error 66.90
# Epoch    13, train loss 1.598000, train error 62.40,  test loss 1.651692, test error 66.20
# Epoch    14, train loss 1.599208, train error 62.72,  test loss 1.659366, test error 67.00
# Epoch    15, train loss 1.596873, train error 62.67,  test loss 1.657452, test error 66.80
# Epoch    16, train loss 1.595013, train error 62.35,  test loss 1.655914, test error 67.70
# Epoch    17, train loss 1.595675, train error 63.50,  test loss 1.655226, test error 67.30
# Epoch    18, train loss 1.596198, train error 62.92,  test loss 1.655310, test error 67.10
# Epoch    19, train loss 1.595366, train error 62.42,  test loss 1.653442, test error 66.00
# Epoch    20, train loss 1.591363, train error 62.85,  test loss 1.650887, test error 66.30
# Epoch    21, train loss 1.591279, train error 62.60,  test loss 1.652297, test error 66.50
# Epoch    22, train loss 1.591836, train error 63.03,  test loss 1.654589, test error 66.70
# Epoch    23, train loss 1.591422, train error 62.42,  test loss 1.654843, test error 66.50
# Epoch    24, train loss 1.591028, train error 62.92,  test loss 1.652360, test error 67.10
# Epoch    25, train loss 1.590429, train error 62.80,  test loss 1.657245, test error 66.70
# Epoch    26, train loss 1.590851, train error 62.62,  test loss 1.656652, test error 66.90
# Epoch    27, train loss 1.590296, train error 62.60,  test loss 1.654075, test error 67.00
# Epoch    28, train loss 1.591194, train error 62.58,  test loss 1.654965, test error 67.20
# Epoch    29, train loss 1.590200, train error 62.60,  test loss 1.657585, test error 67.20
# Epoch    30, train loss 1.589301, train error 62.78,  test loss 1.652811, test error 66.60
# Epoch    31, train loss 1.589274, train error 62.78,  test loss 1.652909, test error 67.00
# Epoch    32, train loss 1.589111, train error 62.58,  test loss 1.654859, test error 67.40
# Epoch    33, train loss 1.589170, train error 62.35,  test loss 1.653488, test error 67.10
# Epoch    34, train loss 1.589037, train error 62.65,  test loss 1.653754, test error 67.30
# Epoch    35, train loss 1.589010, train error 62.75,  test loss 1.652331, test error 66.90
# Epoch    36, train loss 1.588933, train error 62.50,  test loss 1.653703, test error 67.50
# Epoch    37, train loss 1.588922, train error 62.55,  test loss 1.652399, test error 66.50
# Epoch    38, train loss 1.588894, train error 62.58,  test loss 1.653528, test error 66.80
# Epoch    39, train loss 1.588901, train error 62.78,  test loss 1.653681, test error 67.20
# Epoch    40, train loss 1.588624, train error 62.50,  test loss 1.653144, test error 67.30
# Epoch    41, train loss 1.588537, train error 62.70,  test loss 1.653655, test error 67.10
# Epoch    42, train loss 1.588541, train error 62.70,  test loss 1.653929, test error 67.20
# Epoch    43, train loss 1.588471, train error 62.65,  test loss 1.654178, test error 67.40
# Epoch    44, train loss 1.588451, train error 62.47,  test loss 1.652564, test error 66.50
# Epoch    45, train loss 1.588460, train error 62.58,  test loss 1.653529, test error 67.10
# Epoch    46, train loss 1.588397, train error 62.60,  test loss 1.653289, test error 66.90
# Epoch    47, train loss 1.588360, train error 62.70,  test loss 1.652287, test error 66.90
# Epoch    48, train loss 1.588319, train error 62.70,  test loss 1.653264, test error 66.80
# Epoch    49, train loss 1.588319, train error 62.62,  test loss 1.653107, test error 66.70

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TODO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?
