# %% [markdown]
# <a href="https://colab.research.google.com/github/Hitesh171/deeplearningA124002python/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-djmdh3z1
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-djmdh3z1
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (1.15.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.4.26)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14663 sha256=32a56dfb35e7b6fdab6cef280db5177800afd6432f78ab6ffb2544baf27f88d1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-isbe1jss/wheels/d6/38/42/3d2112bc7d915f6195254ac85eb761d922d1b18f52817aa8e2
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.305287, train error 90.15,  test loss 2.304446, test error 89.70
# Epoch   100, train loss 1.905085, train error 71.00,  test loss 1.756780, test error 68.53
# Epoch   200, train loss 1.881260, train error 70.97,  test loss 1.716491, test error 68.20
# Epoch   300, train loss 1.858122, train error 70.20,  test loss 1.700492, test error 67.72
# Epoch   400, train loss 1.855579, train error 70.40,  test loss 1.697658, test error 67.35
# Epoch   500, train loss 1.853886, train error 70.47,  test loss 1.705982, test error 67.50
# Epoch   600, train loss 1.868349, train error 71.03,  test loss 1.702543, test error 68.05
# Epoch   700, train loss 1.857655, train error 70.40,  test loss 1.695580, test error 68.15
# Epoch   800, train loss 1.860359, train error 70.38,  test loss 1.706170, test error 67.47
# Epoch   900, train loss 1.860119, train error 70.68,  test loss 1.720709, test error 69.03
# Training model with   4 hidden variables
# Epoch     0, train loss 2.272576, train error 86.90,  test loss 2.260183, test error 86.65
# Epoch   100, train loss 1.784389, train error 67.38,  test loss 1.628416, test error 63.95
# Epoch   200, train loss 1.756565, train error 65.97,  test loss 1.614841, test error 63.65
# Epoch   300, train loss 1.750503, train error 65.82,  test loss 1.619760, test error 63.30
# Epoch   400, train loss 1.739157, train error 65.38,  test loss 1.600958, test error 62.70
# Epoch   500, train loss 1.739906, train error 64.47,  test loss 1.595588, test error 61.65
# Epoch   600, train loss 1.734494, train error 65.95,  test loss 1.600555, test error 61.78
# Epoch   700, train loss 1.737313, train error 65.15,  test loss 1.589705, test error 61.45
# Epoch   800, train loss 1.738371, train error 65.47,  test loss 1.596893, test error 61.33
# Epoch   900, train loss 1.731248, train error 64.15,  test loss 1.570775, test error 60.88
# Training model with   6 hidden variables
# Epoch     0, train loss 2.272498, train error 86.93,  test loss 2.273356, test error 87.55
# Epoch   100, train loss 1.684785, train error 59.50,  test loss 1.490615, test error 56.28
# Epoch   200, train loss 1.645503, train error 58.72,  test loss 1.461454, test error 55.75
# Epoch   300, train loss 1.643618, train error 59.35,  test loss 1.466597, test error 55.78
# Epoch   400, train loss 1.628738, train error 57.85,  test loss 1.457231, test error 55.78
# Epoch   500, train loss 1.626148, train error 57.60,  test loss 1.460395, test error 55.50
# Epoch   600, train loss 1.633850, train error 58.25,  test loss 1.473052, test error 56.33
# Epoch   700, train loss 1.629070, train error 58.47,  test loss 1.462085, test error 56.20
# Epoch   800, train loss 1.622029, train error 58.00,  test loss 1.453881, test error 55.67
# Epoch   900, train loss 1.615929, train error 56.97,  test loss 1.453535, test error 55.40
# Training model with   8 hidden variables
# Epoch     0, train loss 2.276540, train error 85.80,  test loss 2.274278, test error 85.05
# Epoch   100, train loss 1.617613, train error 57.65,  test loss 1.451913, test error 57.05
# Epoch   200, train loss 1.561158, train error 54.75,  test loss 1.425576, test error 55.35
# Epoch   300, train loss 1.547628, train error 55.35,  test loss 1.429909, test error 54.92
# Epoch   400, train loss 1.530913, train error 54.58,  test loss 1.417583, test error 54.08
# Epoch   500, train loss 1.529784, train error 53.88,  test loss 1.423636, test error 53.90
# Epoch   600, train loss 1.518866, train error 54.42,  test loss 1.424927, test error 54.20
# Epoch   700, train loss 1.520070, train error 54.38,  test loss 1.429159, test error 54.78
# Epoch   800, train loss 1.512335, train error 53.92,  test loss 1.430063, test error 55.62
# Epoch   900, train loss 1.510732, train error 54.20,  test loss 1.429484, test error 54.92
# Training model with  10 hidden variables
# Epoch     0, train loss 2.267840, train error 85.50,  test loss 2.266089, test error 85.75
# Epoch   100, train loss 1.524079, train error 52.85,  test loss 1.388669, test error 52.67
# Epoch   200, train loss 1.420038, train error 47.83,  test loss 1.278370, test error 47.00
# Epoch   300, train loss 1.385293, train error 46.35,  test loss 1.252415, test error 46.03
# Epoch   400, train loss 1.370234, train error 45.65,  test loss 1.263979, test error 46.03
# Epoch   500, train loss 1.360935, train error 45.97,  test loss 1.264390, test error 45.83
# Epoch   600, train loss 1.351748, train error 45.38,  test loss 1.265841, test error 45.92
# Epoch   700, train loss 1.347193, train error 46.08,  test loss 1.268229, test error 46.85
# Epoch   800, train loss 1.339935, train error 44.92,  test loss 1.271539, test error 47.00
# Epoch   900, train loss 1.338669, train error 45.65,  test loss 1.282531, test error 48.08
# Training model with  14 hidden variables
# Epoch     0, train loss 2.185065, train error 80.53,  test loss 2.161949, test error 79.65
# Epoch   100, train loss 1.423468, train error 48.22,  test loss 1.310310, test error 49.30
# Epoch   200, train loss 1.351581, train error 45.12,  test loss 1.320063, test error 49.78
# Epoch   300, train loss 1.317246, train error 43.70,  test loss 1.326191, test error 49.45
# Epoch   400, train loss 1.305057, train error 43.58,  test loss 1.350661, test error 50.60
# Epoch   500, train loss 1.284078, train error 42.88,  test loss 1.338238, test error 49.30
# Epoch   600, train loss 1.288463, train error 43.55,  test loss 1.352123, test error 49.38
# Epoch   700, train loss 1.272362, train error 43.05,  test loss 1.345314, test error 49.60
# Epoch   800, train loss 1.263350, train error 42.65,  test loss 1.368481, test error 49.53
# Epoch   900, train loss 1.259822, train error 42.15,  test loss 1.372509, test error 49.88
# Training model with  18 hidden variables
# Epoch     0, train loss 2.246101, train error 84.05,  test loss 2.254034, test error 84.22
# Epoch   100, train loss 1.326766, train error 44.42,  test loss 1.284368, test error 47.00
# Epoch   200, train loss 1.235327, train error 41.58,  test loss 1.337307, test error 48.65
# Epoch   300, train loss 1.191580, train error 40.35,  test loss 1.353293, test error 48.95
# Epoch   400, train loss 1.159071, train error 38.58,  test loss 1.407806, test error 49.47
# Epoch   500, train loss 1.142826, train error 38.72,  test loss 1.446509, test error 50.35
# Epoch   600, train loss 1.131549, train error 38.28,  test loss 1.475906, test error 50.42
# Epoch   700, train loss 1.121993, train error 38.15,  test loss 1.529733, test error 51.95
# Epoch   800, train loss 1.108496, train error 37.92,  test loss 1.552156, test error 50.70
# Epoch   900, train loss 1.096239, train error 36.90,  test loss 1.572783, test error 51.58
# Training model with  22 hidden variables
# Epoch     0, train loss 2.185609, train error 79.20,  test loss 2.161653, test error 78.75
# Epoch   100, train loss 1.277393, train error 42.55,  test loss 1.338675, test error 49.33
# Epoch   200, train loss 1.171900, train error 39.08,  test loss 1.369494, test error 49.90
# Epoch   300, train loss 1.143212, train error 38.47,  test loss 1.421172, test error 50.20
# Epoch   400, train loss 1.093052, train error 36.78,  test loss 1.442727, test error 50.58
# Epoch   500, train loss 1.076479, train error 37.05,  test loss 1.494008, test error 50.88
# Epoch   600, train loss 1.055897, train error 36.72,  test loss 1.523333, test error 51.05
# Epoch   700, train loss 1.061463, train error 36.00,  test loss 1.549718, test error 51.42
# Epoch   800, train loss 1.041233, train error 36.05,  test loss 1.590293, test error 52.05
# Epoch   900, train loss 1.026562, train error 35.38,  test loss 1.589312, test error 51.22
# Training model with  26 hidden variables
# Epoch     0, train loss 2.173631, train error 79.90,  test loss 2.155698, test error 79.88
# Epoch   100, train loss 1.185805, train error 38.97,  test loss 1.293508, test error 48.58
# Epoch   200, train loss 1.045630, train error 35.32,  test loss 1.419520, test error 49.12
# Epoch   300, train loss 0.957254, train error 32.32,  test loss 1.512150, test error 50.95
# Epoch   400, train loss 0.921702, train error 31.72,  test loss 1.635939, test error 51.88
# Epoch   500, train loss 0.904358, train error 31.53,  test loss 1.726936, test error 53.47
# Epoch   600, train loss 0.855032, train error 29.72,  test loss 1.776133, test error 53.03
# Epoch   700, train loss 0.847729, train error 29.50,  test loss 1.874213, test error 54.12
# Epoch   800, train loss 0.826684, train error 28.45,  test loss 1.907190, test error 53.15
# Epoch   900, train loss 0.815932, train error 28.15,  test loss 1.976241, test error 53.72
# Training model with  30 hidden variables
# Epoch     0, train loss 2.193655, train error 80.43,  test loss 2.181391, test error 81.12
# Epoch   100, train loss 1.081927, train error 35.57,  test loss 1.342523, test error 48.15
# Epoch   200, train loss 0.903541, train error 29.20,  test loss 1.579899, test error 51.22
# Epoch   300, train loss 0.805863, train error 27.10,  test loss 1.820927, test error 51.90
# Epoch   400, train loss 0.747999, train error 24.47,  test loss 1.996320, test error 52.80
# Epoch   500, train loss 0.736176, train error 24.55,  test loss 2.158928, test error 53.47
# Epoch   600, train loss 0.691337, train error 22.72,  test loss 2.264971, test error 53.97
# Epoch   700, train loss 0.677572, train error 21.78,  test loss 2.382606, test error 53.97
# Epoch   800, train loss 0.674478, train error 22.45,  test loss 2.527384, test error 54.83
# Epoch   900, train loss 0.659552, train error 22.07,  test loss 2.560696, test error 53.58
# Training model with  35 hidden variables
# Epoch     0, train loss 2.154673, train error 79.47,  test loss 2.108551, test error 78.12
# Epoch   100, train loss 0.996113, train error 33.10,  test loss 1.403670, test error 49.38
# Epoch   200, train loss 0.785418, train error 25.12,  test loss 1.728881, test error 51.83
# Epoch   300, train loss 0.655573, train error 21.18,  test loss 2.011625, test error 52.88
# Epoch   400, train loss 0.607241, train error 19.53,  test loss 2.312899, test error 53.35
# Epoch   500, train loss 0.540906, train error 17.70,  test loss 2.630008, test error 54.53
# Epoch   600, train loss 0.530123, train error 18.22,  test loss 2.993675, test error 56.08
# Epoch   700, train loss 0.504768, train error 17.25,  test loss 3.131975, test error 54.70
# Epoch   800, train loss 0.454674, train error 15.40,  test loss 3.545982, test error 56.35
# Epoch   900, train loss 0.447630, train error 15.40,  test loss 3.855699, test error 55.75
# Training model with  40 hidden variables
# Epoch     0, train loss 2.178695, train error 79.95,  test loss 2.161530, test error 80.35
# Epoch   100, train loss 0.945719, train error 30.18,  test loss 1.421161, test error 49.17
# Epoch   200, train loss 0.649709, train error 21.18,  test loss 1.957627, test error 52.30
# Epoch   300, train loss 0.493319, train error 15.45,  test loss 2.590703, test error 53.78
# Epoch   400, train loss 0.409315, train error 13.00,  test loss 3.364276, test error 55.08
# Epoch   500, train loss 0.365988, train error 11.88,  test loss 4.074787, test error 56.65
# Epoch   600, train loss 0.302175, train error 9.88,  test loss 4.730614, test error 56.67
# Epoch   700, train loss 0.301508, train error 10.12,  test loss 5.499453, test error 58.30
# Epoch   800, train loss 0.310017, train error 10.55,  test loss 6.109374, test error 56.83
# Epoch   900, train loss 0.272418, train error 10.20,  test loss 6.734904, test error 57.92
# Training model with  45 hidden variables
# Epoch     0, train loss 2.096816, train error 77.95,  test loss 2.061607, test error 77.50
# Epoch   100, train loss 0.831313, train error 26.47,  test loss 1.581175, test error 51.97
# Epoch   200, train loss 0.525389, train error 16.85,  test loss 2.318400, test error 55.00
# Epoch   300, train loss 0.357126, train error 10.20,  test loss 3.289627, test error 55.47
# Epoch   400, train loss 0.261781, train error 7.93,  test loss 4.373989, test error 56.92
# Epoch   500, train loss 0.309726, train error 10.78,  test loss 5.524203, test error 56.97
# Epoch   600, train loss 0.204304, train error 6.47,  test loss 6.570101, test error 57.58
# Epoch   700, train loss 0.141013, train error 4.35,  test loss 7.711080, test error 57.65
# Epoch   800, train loss 0.019552, train error 0.05,  test loss 8.846309, test error 57.92
# Epoch   900, train loss 0.009323, train error 0.00,  test loss 9.756174, test error 58.53
# Training model with  50 hidden variables
# Epoch     0, train loss 2.081697, train error 77.62,  test loss 2.036335, test error 76.72
# Epoch   100, train loss 0.718950, train error 23.62,  test loss 1.594831, test error 50.25
# Epoch   200, train loss 0.356349, train error 11.05,  test loss 2.647297, test error 53.92
# Epoch   300, train loss 0.143933, train error 3.35,  test loss 4.283190, test error 55.85
# Epoch   400, train loss 0.027089, train error 0.05,  test loss 5.793914, test error 55.85
# Epoch   500, train loss 0.012456, train error 0.00,  test loss 6.748097, test error 56.05
# Epoch   600, train loss 0.008033, train error 0.00,  test loss 7.377443, test error 56.10
# Epoch   700, train loss 0.005726, train error 0.00,  test loss 7.829940, test error 56.20
# Epoch   800, train loss 0.004422, train error 0.00,  test loss 8.198007, test error 56.20
# Epoch   900, train loss 0.003602, train error 0.00,  test loss 8.509584, test error 56.33
# Training model with  55 hidden variables
# Epoch     0, train loss 2.117708, train error 78.30,  test loss 2.097495, test error 77.95
# Epoch   100, train loss 0.640869, train error 19.20,  test loss 1.716254, test error 51.75
# Epoch   200, train loss 0.207726, train error 4.50,  test loss 3.074628, test error 53.72
# Epoch   300, train loss 0.040257, train error 0.03,  test loss 4.904550, test error 55.40
# Epoch   400, train loss 0.014494, train error 0.00,  test loss 6.018333, test error 55.40
# Epoch   500, train loss 0.008386, train error 0.00,  test loss 6.678545, test error 55.65
# Epoch   600, train loss 0.005809, train error 0.00,  test loss 7.153091, test error 55.83
# Epoch   700, train loss 0.004305, train error 0.00,  test loss 7.514045, test error 55.78
# Epoch   800, train loss 0.003403, train error 0.00,  test loss 7.818241, test error 55.95
# Epoch   900, train loss 0.002795, train error 0.00,  test loss 8.062253, test error 55.85
# Training model with  60 hidden variables
# Epoch     0, train loss 2.079406, train error 76.97,  test loss 2.054591, test error 76.78
# Epoch   100, train loss 0.539219, train error 15.57,  test loss 1.675045, test error 50.58
# Epoch   200, train loss 0.112944, train error 1.38,  test loss 3.195695, test error 53.22
# Epoch   300, train loss 0.020731, train error 0.00,  test loss 4.558184, test error 54.00
# Epoch   400, train loss 0.009699, train error 0.00,  test loss 5.250144, test error 54.12
# Epoch   500, train loss 0.006123, train error 0.00,  test loss 5.708457, test error 54.20
# Epoch   600, train loss 0.004322, train error 0.00,  test loss 6.042171, test error 54.17
# Epoch   700, train loss 0.003315, train error 0.00,  test loss 6.313025, test error 54.35
# Epoch   800, train loss 0.002665, train error 0.00,  test loss 6.539108, test error 54.33
# Epoch   900, train loss 0.002200, train error 0.00,  test loss 6.723679, test error 54.40
# Training model with  70 hidden variables
# Epoch     0, train loss 2.036506, train error 75.78,  test loss 1.983978, test error 74.70
# Epoch   100, train loss 0.345230, train error 8.07,  test loss 1.905101, test error 50.08
# Epoch   200, train loss 0.030313, train error 0.00,  test loss 3.416324, test error 52.83
# Epoch   300, train loss 0.010574, train error 0.00,  test loss 4.122296, test error 52.65
# Epoch   400, train loss 0.005913, train error 0.00,  test loss 4.527859, test error 52.85
# Epoch   500, train loss 0.003980, train error 0.00,  test loss 4.812243, test error 52.90
# Epoch   600, train loss 0.002945, train error 0.00,  test loss 5.026669, test error 53.10
# Epoch   700, train loss 0.002317, train error 0.00,  test loss 5.200658, test error 53.15
# Epoch   800, train loss 0.001893, train error 0.00,  test loss 5.348863, test error 53.22
# Epoch   900, train loss 0.001592, train error 0.00,  test loss 5.473047, test error 53.20
# Training model with  80 hidden variables
# Epoch     0, train loss 2.021701, train error 76.43,  test loss 1.948327, test error 74.22
# Epoch   100, train loss 0.223060, train error 3.53,  test loss 2.099838, test error 52.65
# Epoch   200, train loss 0.019378, train error 0.00,  test loss 3.456104, test error 53.65
# Epoch   300, train loss 0.007914, train error 0.00,  test loss 4.003079, test error 53.53
# Epoch   400, train loss 0.004702, train error 0.00,  test loss 4.328415, test error 53.65
# Epoch   500, train loss 0.003258, train error 0.00,  test loss 4.563540, test error 53.75
# Epoch   600, train loss 0.002457, train error 0.00,  test loss 4.745109, test error 53.62
# Epoch   700, train loss 0.001952, train error 0.00,  test loss 4.892578, test error 53.55
# Epoch   800, train loss 0.001609, train error 0.00,  test loss 5.016443, test error 53.50
# Epoch   900, train loss 0.001363, train error 0.00,  test loss 5.124302, test error 53.50
# Training model with  90 hidden variables
# Epoch     0, train loss 2.003783, train error 74.88,  test loss 1.915112, test error 73.50
# Epoch   100, train loss 0.150073, train error 1.15,  test loss 2.135316, test error 50.65
# Epoch   200, train loss 0.015002, train error 0.00,  test loss 3.156448, test error 51.10
# Epoch   300, train loss 0.006605, train error 0.00,  test loss 3.573816, test error 51.08
# Epoch   400, train loss 0.003999, train error 0.00,  test loss 3.838180, test error 51.25
# Epoch   500, train loss 0.002807, train error 0.00,  test loss 4.023458, test error 51.28
# Epoch   600, train loss 0.002133, train error 0.00,  test loss 4.168379, test error 51.30
# Epoch   700, train loss 0.001704, train error 0.00,  test loss 4.286570, test error 51.33
# Epoch   800, train loss 0.001410, train error 0.00,  test loss 4.387980, test error 51.25
# Epoch   900, train loss 0.001198, train error 0.00,  test loss 4.475445, test error 51.17
# Training model with 100 hidden variables
# Epoch     0, train loss 2.015283, train error 74.68,  test loss 1.978282, test error 74.62
# Epoch   100, train loss 0.081638, train error 0.05,  test loss 2.150627, test error 49.58
# Epoch   200, train loss 0.011831, train error 0.00,  test loss 2.936312, test error 49.85
# Epoch   300, train loss 0.005563, train error 0.00,  test loss 3.279638, test error 49.67
# Epoch   400, train loss 0.003484, train error 0.00,  test loss 3.494098, test error 49.58
# Epoch   500, train loss 0.002481, train error 0.00,  test loss 3.654097, test error 49.55
# Epoch   600, train loss 0.001904, train error 0.00,  test loss 3.777537, test error 49.62
# Epoch   700, train loss 0.001532, train error 0.00,  test loss 3.880456, test error 49.65
# Epoch   800, train loss 0.001274, train error 0.00,  test loss 3.968585, test error 49.78
# Epoch   900, train loss 0.001086, train error 0.00,  test loss 4.044417, test error 49.70
# Training model with 120 hidden variables
# Epoch     0, train loss 1.962248, train error 72.80,  test loss 1.903247, test error 74.38
# Epoch   100, train loss 0.048425, train error 0.00,  test loss 2.177680, test error 50.03
# Epoch   200, train loss 0.009184, train error 0.00,  test loss 2.747825, test error 49.65
# Epoch   300, train loss 0.004583, train error 0.00,  test loss 3.009738, test error 49.30
# Epoch   400, train loss 0.002940, train error 0.00,  test loss 3.180386, test error 49.20
# Epoch   500, train loss 0.002123, train error 0.00,  test loss 3.305706, test error 49.38
# Epoch   600, train loss 0.001641, train error 0.00,  test loss 3.405089, test error 49.47
# Epoch   700, train loss 0.001328, train error 0.00,  test loss 3.487611, test error 49.53
# Epoch   800, train loss 0.001109, train error 0.00,  test loss 3.557789, test error 49.53
# Epoch   900, train loss 0.000949, train error 0.00,  test loss 3.619501, test error 49.65
# Training model with 140 hidden variables
# Epoch     0, train loss 1.946775, train error 71.60,  test loss 1.881595, test error 72.68
# Epoch   100, train loss 0.033190, train error 0.00,  test loss 2.220809, test error 49.30
# Epoch   200, train loss 0.007792, train error 0.00,  test loss 2.704305, test error 48.67
# Epoch   300, train loss 0.004030, train error 0.00,  test loss 2.936249, test error 48.88
# Epoch   400, train loss 0.002630, train error 0.00,  test loss 3.087494, test error 48.80
# Epoch   500, train loss 0.001918, train error 0.00,  test loss 3.201433, test error 48.67
# Epoch   600, train loss 0.001493, train error 0.00,  test loss 3.292067, test error 48.72
# Epoch   700, train loss 0.001214, train error 0.00,  test loss 3.367504, test error 48.72
# Epoch   800, train loss 0.001017, train error 0.00,  test loss 3.431545, test error 48.70
# Epoch   900, train loss 0.000872, train error 0.00,  test loss 3.488076, test error 48.65
# Training model with 160 hidden variables
# Epoch     0, train loss 1.945816, train error 71.68,  test loss 1.846201, test error 70.72
# Epoch   100, train loss 0.028019, train error 0.00,  test loss 2.146672, test error 49.45
# Epoch   200, train loss 0.007098, train error 0.00,  test loss 2.575803, test error 49.50
# Epoch   300, train loss 0.003736, train error 0.00,  test loss 2.786486, test error 49.22
# Epoch   400, train loss 0.002454, train error 0.00,  test loss 2.926302, test error 49.25
# Epoch   500, train loss 0.001796, train error 0.00,  test loss 3.030945, test error 49.08
# Epoch   600, train loss 0.001403, train error 0.00,  test loss 3.113196, test error 49.15
# Epoch   700, train loss 0.001142, train error 0.00,  test loss 3.182929, test error 49.20
# Epoch   800, train loss 0.000959, train error 0.00,  test loss 3.241951, test error 49.35
# Epoch   900, train loss 0.000823, train error 0.00,  test loss 3.294459, test error 49.30
# Training model with 180 hidden variables
# Epoch     0, train loss 1.936769, train error 71.10,  test loss 1.870673, test error 73.22
# Epoch   100, train loss 0.024712, train error 0.00,  test loss 2.011591, test error 48.00
# Epoch   200, train loss 0.006650, train error 0.00,  test loss 2.366946, test error 48.62
# Epoch   300, train loss 0.003552, train error 0.00,  test loss 2.542356, test error 48.53
# Epoch   400, train loss 0.002351, train error 0.00,  test loss 2.660870, test error 48.55
# Epoch   500, train loss 0.001729, train error 0.00,  test loss 2.748637, test error 48.50
# Epoch   600, train loss 0.001354, train error 0.00,  test loss 2.819362, test error 48.58
# Epoch   700, train loss 0.001106, train error 0.00,  test loss 2.878947, test error 48.50
# Epoch   800, train loss 0.000930, train error 0.00,  test loss 2.929317, test error 48.58
# Epoch   900, train loss 0.000799, train error 0.00,  test loss 2.974066, test error 48.45
# Training model with 200 hidden variables
# Epoch     0, train loss 1.931126, train error 70.75,  test loss 1.870637, test error 71.82
# Epoch   100, train loss 0.022227, train error 0.00,  test loss 2.059724, test error 48.28
# Epoch   200, train loss 0.006210, train error 0.00,  test loss 2.388823, test error 48.15
# Epoch   300, train loss 0.003354, train error 0.00,  test loss 2.557749, test error 48.33
# Epoch   400, train loss 0.002231, train error 0.00,  test loss 2.672201, test error 48.45
# Epoch   500, train loss 0.001645, train error 0.00,  test loss 2.758586, test error 48.40
# Epoch   600, train loss 0.001291, train error 0.00,  test loss 2.827261, test error 48.47
# Epoch   700, train loss 0.001055, train error 0.00,  test loss 2.884635, test error 48.47
# Epoch   800, train loss 0.000888, train error 0.00,  test loss 2.933949, test error 48.47
# Epoch   900, train loss 0.000764, train error 0.00,  test loss 2.977088, test error 48.60
# Training model with 250 hidden variables
# Epoch     0, train loss 1.918220, train error 70.55,  test loss 1.860973, test error 71.53
# Epoch   100, train loss 0.017630, train error 0.00,  test loss 1.994230, test error 48.62
# Epoch   200, train loss 0.005401, train error 0.00,  test loss 2.247963, test error 48.35
# Epoch   300, train loss 0.002999, train error 0.00,  test loss 2.386233, test error 48.38
# Epoch   400, train loss 0.002023, train error 0.00,  test loss 2.480144, test error 48.33
# Epoch   500, train loss 0.001503, train error 0.00,  test loss 2.550594, test error 48.30
# Epoch   600, train loss 0.001185, train error 0.00,  test loss 2.607947, test error 48.33
# Epoch   700, train loss 0.000973, train error 0.00,  test loss 2.655499, test error 48.30
# Epoch   800, train loss 0.000821, train error 0.00,  test loss 2.696432, test error 48.22
# Epoch   900, train loss 0.000708, train error 0.00,  test loss 2.732108, test error 48.35
# Training model with 300 hidden variables
# Epoch     0, train loss 1.860152, train error 67.82,  test loss 1.784901, test error 70.22
# Epoch   100, train loss 0.014448, train error 0.00,  test loss 1.859433, test error 46.40
# Epoch   200, train loss 0.004789, train error 0.00,  test loss 2.075599, test error 46.42
# Epoch   300, train loss 0.002710, train error 0.00,  test loss 2.191825, test error 46.45
# Epoch   400, train loss 0.001845, train error 0.00,  test loss 2.272664, test error 46.53
# Epoch   500, train loss 0.001381, train error 0.00,  test loss 2.333993, test error 46.50
# Epoch   600, train loss 0.001094, train error 0.00,  test loss 2.383804, test error 46.47
# Epoch   700, train loss 0.000901, train error 0.00,  test loss 2.425495, test error 46.42
# Epoch   800, train loss 0.000763, train error 0.00,  test loss 2.461330, test error 46.38
# Epoch   900, train loss 0.000659, train error 0.00,  test loss 2.493090, test error 46.35
# Training model with 400 hidden variables
# Epoch     0, train loss 1.845651, train error 65.93,  test loss 1.776256, test error 69.03
# Epoch   100, train loss 0.011765, train error 0.00,  test loss 1.721397, test error 45.30
# Epoch   200, train loss 0.004193, train error 0.00,  test loss 1.893357, test error 45.20
# Epoch   300, train loss 0.002424, train error 0.00,  test loss 1.987903, test error 45.20
# Epoch   400, train loss 0.001669, train error 0.00,  test loss 2.053810, test error 45.22
# Epoch   500, train loss 0.001257, train error 0.00,  test loss 2.104200, test error 45.15
# Epoch   600, train loss 0.001001, train error 0.00,  test loss 2.144893, test error 45.10
# Epoch   700, train loss 0.000827, train error 0.00,  test loss 2.179780, test error 45.10
# Epoch   800, train loss 0.000702, train error 0.00,  test loss 2.209614, test error 45.15
# Epoch   900, train loss 0.000608, train error 0.00,  test loss 2.235887, test error 45.15

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
